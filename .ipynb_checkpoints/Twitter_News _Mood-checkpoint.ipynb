# %%
# 1. Fox News is by far the most negative 
# 2. NY times is the most neutral with CNN as the close second
# 3. Vader analysis of news is subject to what happened on a particular day, 
#  so this test should be ran over a long period of time.

# %%
import tweepy
import json
import pandas as pd
import numpy as np
import time
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
consumer_key = "4JPyi4nFzwCJTxf2M6WzKj1xe"
consumer_secret = "JK62tMorfWHYRTQyJggN6JJSra4MHag6h7QLolvWtMVrZ1h0cy"
access_token = "27365820-SLlpBaUtl0ITSCZe9Tdm6nCzpe3Quc4ZPsKyjyDUV"
access_token_secret = "L54XxUoSjFnLsXd0zDHfG57ziW2hE5PmdOm0OLmA3D47z"

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
sentiments = []

target_users = ("@BBC", "@CBS", "@CNN", "@FoxNews", "@NYTimes")

# %%
for user in target_users:
    counter = 0
    public_tweets = api.user_timeline(user, count = 100)
    
    for tweet in public_tweets:
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        tweets_ago = counter
        tweet_text = tweet["text"]
        sentiments.append({"User" : user,
                           "Date": tweet["created_at"],
                           "Compound" : compound,
                           "Positive" : pos,
                           "Negative" : neg,
                           "Neutral" : neu,
                           "Tweets Ago" : counter,
                           "Tweet Text" : tweet_text})
        counter = counter + 1

# %%
news_sentiments = pd.DataFrame.from_dict(sentiments)
news_sentiments
# Out:
#      Compound                            Date  Negative  Neutral  Positive  \
# 0      0.0772  Mon Sep 17 18:04:04 +0000 2018     0.000    0.929     0.071
# 1      0.0000  Mon Sep 17 17:04:05 +0000 2018     0.000    1.000     0.000
# 2      0.6996  Mon Sep 17 16:04:02 +0000 2018     0.000    0.674     0.326
# 3      0.0000  Mon Sep 17 15:03:04 +0000 2018     0.000    1.000     0.000
# 4     -0.5574  Mon Sep 17 14:03:05 +0000 2018     0.146    0.854     0.000
# 5      0.4404  Mon Sep 17 13:04:04 +0000 2018     0.000    0.791     0.209
# 6      0.7184  Mon Sep 17 12:02:06 +0000 2018     0.000    0.708     0.292
# 7      0.0000  Mon Sep 17 11:27:23 +0000 2018     0.000    1.000     0.000
# 8      0.0000  Mon Sep 17 11:03:04 +0000 2018     0.000    1.000     0.000
# 9      0.0000  Mon Sep 17 10:03:05 +0000 2018     0.000    1.000     0.000
# 10     0.0000  Mon Sep 17 09:04:06 +0000 2018     0.000    1.000     0.000
# 11     0.5994  Mon Sep 17 08:02:03 +0000 2018     0.000    0.755     0.245
# 12     0.5719  Mon Sep 17 07:31:08 +0000 2018     0.000    0.802     0.198
# 13     0.0000  Mon Sep 17 07:03:05 +0000 2018     0.000    1.000     0.000
# 14     0.4767  Sun Sep 16 19:17:07 +0000 2018     0.000    0.838     0.162
# 15     0.0000  Sun Sep 16 17:04:06 +0000 2018     0.000    1.000     0.000
# 16     0.0000  Sun Sep 16 16:02:03 +0000 2018     0.000    1.000     0.000
# 17     0.0000  Sun Sep 16 15:03:04 +0000 2018     0.000    1.000     0.000
# 18    -0.1531  Sun Sep 16 14:04:05 +0000 2018     0.176    0.676     0.149
# 19     0.0000  Sun Sep 16 14:01:39 +0000 2018     0.000    1.000     0.000
# 494   -0.6705  Mon Sep 17 07:00:04 +0000 2018     0.244    0.756     0.000
# 495    0.7964  Mon Sep 17 06:59:48 +0000 2018     0.000    0.705     0.295
# 496    0.0000  Mon Sep 17 06:45:02 +0000 2018     0.000    1.000     0.000
# 497   -0.2732  Mon Sep 17 06:30:07 +0000 2018     0.130    0.870     0.000
# 498    0.0000  Mon Sep 17 06:15:05 +0000 2018     0.000    1.000     0.000
# 499   -0.6243  Mon Sep 17 06:00:06 +0000 2018     0.170    0.830     0.000
#
#                                             Tweet Text  Tweets Ago      User
# 0    University Challenge icons @e_monkman and @Bob...           0      @BBC
# 1    Australia has ordered an investigation into th...           1      @BBC
# 2    The finalists of the Comedy Wildlife Photograp...           2      @BBC
# 3    Who knew Paddington had such a foul mouth?! 😱🐻...           3      @BBC
# 4    The UK's oldest person has seen the outbreak a...           4      @BBC
# 5    This is truly magical: Sue and her underwater ...           5      @BBC
# 6    The Duchess of Sussex has launched her first s...           6      @BBC
# 7    RT @bbcpress: 🏴󠁧󠁢󠁷󠁬󠁳󠁿 @larrylamb47 leads cast ...           7      @BBC
# 8    🌟🌠✨ The International Dark Sky Association has...           8      @BBC
# 9    Meet Vera, a 102-year-old Manchester City masc...           9      @BBC
# 10   Your week, as told by @louistheroux...\n\nhttp...          10      @BBC
# 11   This spectacular 'super bloom' has transformed...          11      @BBC
# 12   ✅ Courgetti spaghetti\n✅ Chicken kebab wrap\n✅...          12      @BBC
# 13   🌧️ 🤔 This man claims he can control the rain, ...          13      @BBC
# 14   Riding on some types of roller-coaster is an e...          14      @BBC
# 15   From overnight oats to kids' fruit cobbler: he...          15      @BBC
# 16   From Viola Davis to Robert Pattinson: these ar...          16      @BBC
# 17   "You cannot make clothes without pockets!" \n\...          17      @BBC
# 18   A new scientific study suggests that there are...          18      @BBC
# 19   RT @BBCSport: We ❤️ Vera! https://t.co/4jTELqBPBv          19      @BBC
# 20   This is unbelievable! 👕📲️⚽️\n\nSam is 17 and s...          20      @BBC
# 21   "If someone offered me my arms back, I wouldn'...          21      @BBC
# 22   😂😂😂 @kenjeong's laugh is ICONIC. \n\n@crazyric...          22      @BBC
# 23   Space race! 🚀🏃⭐️\n\n@usainbolt is just as grea...          23      @BBC
# 24   RT @bbcthree: All your fav bits from Ep 1 in o...          24      @BBC
# 25   “Singapore is a character in this film”: @gemm...          25      @BBC
# 26   Can cold water swimming treat depression? 💙 ht...          26      @BBC
# 27   These beautiful fish have devastating effects ...          27      @BBC
# 28   🐮🤔🐐 Do you know your beef from your GOAT? \n\n...          28      @BBC
# 29   Spying, obsession, murder. @iamsandraoh and @j...          29      @BBC
# ..                                                 ...         ...       ...
# 470  Eliud Kipchoge, who is widely regarded as the ...          70  @NYTimes
# 471  A man was killed by a shark off Cape Cod over ...          71  @NYTimes
# 472  Your daily @DealBook Briefing:\n\n• Top busine...          72  @NYTimes
# 473  "It's easy to say, 'I love God,' but put on yo...          73  @NYTimes
# 474  There's no doubt Tesla and Elon Musk have plen...          74  @NYTimes
# 475  The man stood casually on the subway tracks, h...          75  @NYTimes
# 476  North Carolina is facing a statewide crisis as...          76  @NYTimes
# 477  Molly Kelly fended off a challenge from the le...          77  @NYTimes
# 478  Soon-Yi Previn said starting a relationship wi...          78  @NYTimes
# 479  There has been another huge misinformation cam...          79  @NYTimes
# 480  A woman who accuses Supreme Court nominee Bret...          80  @NYTimes
# 481  Michael Bloomberg may run for President as a D...          81  @NYTimes
# 482  Morning Briefing: Here's what you need to know...          82  @NYTimes
# 483  RT @nytimesworld: Museums are where we tell st...          83  @NYTimes
# 484  "North Korea will highlight the discrepancy: '...          84  @NYTimes
# 485  RT @JackEwingNYT: I still say the evolution of...          85  @NYTimes
# 486  7 years after @sweden began giving ordinary Sw...          86  @NYTimes
# 487  The first full-dress retrospective in North Am...          87  @NYTimes
# 488  How do companies regain public trust after som...          88  @NYTimes
# 489  The Russia spy scandal has claimed another vic...          89  @NYTimes
# 490  RT @stevenleemyers: In Yangjiang, broken glass...          90  @NYTimes
# 491  More than 230,000 infants were treated in emer...          91  @NYTimes
# 492  The air travel disruptions that rippled across...          92  @NYTimes
# 493  3 concrete tips that will help you become a mo...          93  @NYTimes
# 494  As President Trump ratchets up the trade war w...          94  @NYTimes
# 495  RT @davidenrich: This is my favorite page in t...          95  @NYTimes
# 496  A day after Typhoon Mangkhut tore through the ...          96  @NYTimes
# 497  U.S. prosecutors have quietly dismissed charge...          97  @NYTimes
# 498  After 5 elections over 17 years, costing about...          98  @NYTimes
# 499  With the deal for Time, the Benioffs have pick...          99  @NYTimes
#
# [500 rows x 8 columns]

# %%
news_sentiments.to_csv("Twitter_News_Mood.csv", index=False)

# %%
plt.xlim(101, -1)

for user in target_users:
    dataframe = news_sentiments.loc[news_sentiments["User"] == user]
    plt.scatter(dataframe["Tweets Ago"],dataframe["Compound"],label = user)
    
plt.legend(bbox_to_anchor = (1,1))

plt.title("Sentiment Analysis of Media Tweets (11/5/2017)")
plt.xlabel("Tweets Ago")
plt.ylabel("Tweet Polarity")

plt.grid()

plt.savefig("Sentiment Analysis of Media Tweets")
plt.show()

# %%
average_sentiment = news_sentiments.groupby("User")["Compound"].mean()
average_sentiment
# Out:
# User
# @BBC        0.136322
# @CBS        0.148609
# @CNN        0.036104
# @FoxNews   -0.092915
# @NYTimes   -0.005909
# Name: Compound, dtype: float64

# %%
x_axis  =  np.arange(len(average_sentiment))
xlabels = average_sentiment.index
count = 0
for sentiment in average_sentiment:
    plt.text(count, sentiment+.01, str(round(sentiment,2)))
    count = count + 1
plt.bar(x_axis, average_sentiment, tick_label = xlabels, color = ['silver', 'b', 'y', 'g', 'c'])
#Set title, x axis label, and y axis label.
plt.title("Overall Sentiment of Media Tweets (11/5/2017)")
plt.xlabel("New Organizations")
plt.ylabel("Tweet Polarity")
plt.savefig("Overall Sentiment of Media Tweets")
plt.show()
